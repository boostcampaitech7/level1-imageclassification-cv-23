# %%
# !git clone https://github.com/uoguelph-mlrg/Cutout.git
# !git clone https://github.com/DeepVoltaire/AutoAugment.git
# Out:
# Cloning into 'Cutout'...
# remote: Enumerating objects: 138, done.
# remote: Total 138 (delta 0), reused 0 (delta 0), pack-reused 138 (from 1)
# Receiving objects: 100% (138/138), 69.89 KiB | 1.18 MiB/s, done.
# Resolving deltas: 100% (62/62), done.
# Cloning into 'AutoAugment'...
# remote: Enumerating objects: 153, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 153 (delta 6), reused 13 (delta 6), pack-reused 136 (from 1)
# Receiving objects: 100% (153/153), 35.60 MiB | 11.90 MiB/s, done.
# Resolving deltas: 100% (74/74), done.

# %%
from torchvision import transforms

from AutoAugment.autoaugment import ImageNetPolicy
policy = ImageNetPolicy()
train_aug=transforms.Compose([
                         transforms.RandomHorizontalFlip(),
                         transforms.RandomVerticalFlip(),
                         ImageNetPolicy(),
			             transforms.ToTensor(),
                         transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))]
                        )


valid_aug=transforms.Compose([
                        transforms.ToTensor(),
                        transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
                        ])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 4
#       1 from torchvision import transforms
#       3 from AutoAugment.autoaugment import ImageNetPolicy
# ----> 4 policy = ImageNetPolicy()
#       5 train_aug=transforms.Compose([
#       6                          transforms.RandomHorizontalFlip(),
#       7                          transforms.RandomVerticalFlip(),
#    (...)
#      10                          transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))]
#      11                         )
#      14 valid_aug=transforms.Compose([
#      15                         transforms.ToTensor(),
#      16                         transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
#      17                         ])
#
# File ~/jh_aug_test/level1-imageclassification-cv-23/src/AutoAugment/autoaugment.py:20, in ImageNetPolicy.__init__(self, fillcolor)
#      18 def __init__(self, fillcolor=(128, 128, 128)):
#      19     self.policies = [
# ---> 20         SubPolicy(0.4, "posterize", 8, 0.6, "rotate", 9, fillcolor),
#      21         SubPolicy(0.6, "solarize", 5, 0.6, "autocontrast", 5, fillcolor),
#      22         SubPolicy(0.8, "equalize", 8, 0.6, "equalize", 3, fillcolor),
#      23         SubPolicy(0.6, "posterize", 7, 0.6, "posterize", 6, fillcolor),
#      24         SubPolicy(0.4, "equalize", 7, 0.2, "solarize", 4, fillcolor),
#      25
#      26         SubPolicy(0.4, "equalize", 4, 0.8, "rotate", 8, fillcolor),
#      27         SubPolicy(0.6, "solarize", 3, 0.6, "equalize", 7, fillcolor),
#      28         SubPolicy(0.8, "posterize", 5, 1.0, "equalize", 2, fillcolor),
#      29         SubPolicy(0.2, "rotate", 3, 0.6, "solarize", 8, fillcolor),
#      30         SubPolicy(0.6, "equalize", 8, 0.4, "posterize", 6, fillcolor),
#      31
#      32         SubPolicy(0.8, "rotate", 8, 0.4, "color", 0, fillcolor),
#      33         SubPolicy(0.4, "rotate", 9, 0.6, "equalize", 2, fillcolor),
#      34         SubPolicy(0.0, "equalize", 7, 0.8, "equalize", 8, fillcolor),
#      35         SubPolicy(0.6, "invert", 4, 1.0, "equalize", 8, fillcolor),
#      36         SubPolicy(0.6, "color", 4, 1.0, "contrast", 8, fillcolor),
#      37
#      38         SubPolicy(0.8, "rotate", 8, 1.0, "color", 2, fillcolor),
#      39         SubPolicy(0.8, "color", 8, 0.8, "solarize", 7, fillcolor),
#      40         SubPolicy(0.4, "sharpness", 7, 0.6, "invert", 8, fillcolor),
#      41         SubPolicy(0.6, "shearX", 5, 1.0, "equalize", 9, fillcolor),
#      42         SubPolicy(0.4, "color", 0, 0.6, "equalize", 3, fillcolor),
#      43
#      44         SubPolicy(0.4, "equalize", 7, 0.2, "solarize", 4, fillcolor),
#      45         SubPolicy(0.6, "solarize", 5, 0.6, "autocontrast", 5, fillcolor),
#      46         SubPolicy(0.6, "invert", 4, 1.0, "equalize", 8, fillcolor),
#      47         SubPolicy(0.6, "color", 4, 1.0, "contrast", 8, fillcolor),
#      48         SubPolicy(0.8, "equalize", 8, 0.6, "equalize", 3, fillcolor)
#      49     ]
#
# File ~/jh_aug_test/level1-imageclassification-cv-23/src/AutoAugment/autoaugment.py:176, in SubPolicy.__init__(self, p1, operation1, magnitude_idx1, p2, operation2, magnitude_idx2, fillcolor)
#     168 def __init__(self, p1, operation1, magnitude_idx1, p2, operation2, magnitude_idx2, fillcolor=(128, 128, 128)):
#     169     ranges = {
#     170         "shearX": np.linspace(0, 0.3, 10),
#     171         "shearY": np.linspace(0, 0.3, 10),
#     172         "translateX": np.linspace(0, 150 / 331, 10),
#     173         "translateY": np.linspace(0, 150 / 331, 10),
#     174         "rotate": np.linspace(0, 30, 10),
#     175         "color": np.linspace(0.0, 0.9, 10),
# --> 176         "posterize": np.round(np.linspace(8, 4, 10), 0).astype(np.int),
#     177         "solarize": np.linspace(256, 0, 10),
#     178         "contrast": np.linspace(0.0, 0.9, 10),
#     179         "sharpness": np.linspace(0.0, 0.9, 10),
#     180         "brightness": np.linspace(0.0, 0.9, 10),
#     181         "autocontrast": [0] * 10,
#     182         "equalize": [0] * 10,
#     183         "invert": [0] * 10
#     184     }
#     186     func = {
#     187         "shearX": ShearX(fillcolor=fillcolor),
#     188         "shearY": ShearY(fillcolor=fillcolor),
#    (...)
#     200         "invert": Invert()
#     201     }
#     203     self.p1 = p1
#
# File ~/jh_aug_test/level1-imageclassification-cv-23/ji/lib/python3.10/site-packages/numpy/__init__.py:324, in __getattr__(attr)
#     319     warnings.warn(
#     320         f"In the future `np.{attr}` will be defined as the "
#     321         "corresponding NumPy scalar.", FutureWarning, stacklevel=2)
#     323 if attr in __former_attrs__:
# --> 324     raise AttributeError(__former_attrs__[attr])
#     326 if attr == 'testing':
#     327     import numpy.testing as testing
#
# AttributeError: module 'numpy' has no attribute 'int'.
# `np.int` was a deprecated alias for the builtin `int`. To avoid this error in existing code, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
